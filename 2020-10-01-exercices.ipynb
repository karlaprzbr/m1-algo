# %%
#exo1
A=1
B=2

C=A
A=B
B=C

# %%
#exo2
nb=input("choisir un nombre\n")
print(int(nb)*int(nb))

# %%
#exo3
nb=int(input("choisir un nombre\n"))
if nb < 0 :
  print("ce nombre est negatif")
else :
  print("ce nombre est positif")

# %%
#exo4
nb1=int(input("choisir un nombre\n"))
nb2=int(input("choisir un autre nombre\n"))
if nb1>=0 and nb2>=0 or nb1<=0 and nb2<=0 :
  print("le produit des deux nombres est positif")
else :
  print("le produit des deux nombres est negatif")

# %%
#exo5
nb=int(input("choisir un nombre\n"))
for x in range(1,10) :
  nb+=1
  print(nb)

# %%
#exo6
nb=int(input("choisir un nombre\n"))
retour = 0
for x in range(1,nb):
  retour+=1
  print(retour)
